# %%
import pandas as pd

# %%
#Reading the csv files
heart=pd.read_csv("/content/Heart.csv")
heart.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
#Indexing and selecting the data
heart=pd.read_csv("/content/Heart.csv",index_col="Chol")
first=heart["Age"]
print(first)
# Out:
# Chol
# 233    63
# 286    67
# 229    67
# 250    37
# 204    41
#        ..
# 264    45
# 193    68
# 131    57
# 236    57
# 175    38
# Name: Age, Length: 303, dtype: int64

# %%
#Sorting the data
df=pd.DataFrame(heart)
df.sort_values(by=['Age'])
# Out:
#       Unnamed: 0  Age  Sex     ChestPain  RestBP  Fbs  RestECG  MaxHR  ExAng  \
# Chol
# 204          133   29    1    nontypical     130    0        2    202      0
# 182          102   34    1       typical     118    0        2    174      0
# 210          226   34    0    nontypical     118    0        0    192      0
# 192          284   35    1    nontypical     122    0        0    174      0
# 183          118   35    0  asymptomatic     138    0        0    182      0
# ...          ...  ...  ...           ...     ...  ...      ...    ...    ...
# 302           43   71    0    nontypical     160    0        0    162      0
# 265          104   71    0    nonanginal     110    1        2    130      0
# 269          234   74    0    nontypical     120    0        2    121      1
# 197          258   76    0    nonanginal     140    0        1    116      0
# 304          162   77    1  asymptomatic     125    0        2    162      1
#
# ...

# %%
#Describe Attributes of Data
heart.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP         Fbs     RestECG  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769    0.148515    0.990099
# std     87.612784    9.038662    0.467299   17.599748    0.356198    0.994971
# min      1.000000   29.000000    0.000000   94.000000    0.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000    0.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000    0.000000    1.000000
# 75%    227.500000   61.000000    1.000000  140.000000    0.000000    2.000000
# max    303.000000   77.000000    1.000000  200.000000    1.000000    2.000000
#
#             MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  299.000000
# mean   149.607261    0.326733    1.039604    1.600660    0.672241
# std     22.875003    0.469794    1.161075    0.616226    0.937438
# ...

# %%
#Checking Datatypes of Each Column
df=pd.DataFrame(heart)
df.dtypes
# Out:
# Unnamed: 0      int64
# Age             int64
# Sex             int64
# ChestPain      object
# RestBP          int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
#Counting Unique Values
c=len(pd.unique(df['Age']))
print("No of unique values :",c)
# Out:
# No of unique values : 41

# %%
#Converting data from short to long and vise versa
df.info()
df["Age"]=df["Age"].astype('float')
df.info()
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 233 to 175
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    float64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Fbs         303 non-null    int64
#  6   RestECG     303 non-null    int64
#  7   MaxHR       303 non-null    int64
#  8   ExAng       303 non-null    int64
#  9   Oldpeak     303 non-null    float64
#  10  Slope       303 non-null    int64
#  11  Ca          299 non-null    float64
#  12  Thal        301 non-null    object
#  13  AHD         303 non-null    object
# dtypes: float64(3), int64(8), object(3)
# memory usage: 35.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 233 to 175
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %%
#Finding missing vlaues and replacing it with other values
heart
heart=heart.fillna(1)
heart
# Out:
#       Unnamed: 0  Age  Sex     ChestPain  RestBP  Fbs  RestECG  MaxHR  ExAng  \
# Chol
# 233            1   63    1       typical     145    1        2    150      0
# 286            2   67    1  asymptomatic     160    0        2    108      1
# 229            3   67    1  asymptomatic     120    0        2    129      1
# 250            4   37    1    nonanginal     130    0        0    187      0
# 204            5   41    0    nontypical     130    0        2    172      0
# ...          ...  ...  ...           ...     ...  ...      ...    ...    ...
# 264          299   45    1       typical     110    0        0    132      0
# 193          300   68    1  asymptomatic     144    1        0    141      0
# 131          301   57    1  asymptomatic     130    0        0    115      1
# 236          302   57    0    nontypical     130    0        2    174      0
# 175          303   38    1    nonanginal     138    0        0    173      0
#
# ...
